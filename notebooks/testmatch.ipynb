# %%
from chessai.arena import play_match
from chessai.search.policy import PolicyBot
from chessai.search.random_bot import RandomBot
from chessai.search.material import MaterialBot
import chess 
print(play_match(PolicyBot(ckpt_path="../parameters/ckpt_32000.pt"), MaterialBot(seed=3), nbmatchs=100))
# Out:
# Policy vs material: 98.5 - 1.5

# %%
b = chess.Board()

# %%
b.push_san("e4")


bot = PolicyBot(ckpt_path="../parameters/ckpt_32000.pt")
a = bot.select_move(b)
b.push(bot.select_move(b))


print(a)



# mat wins against random
# Out:
# e7e6

# %%
type(a)
# Out:
# chess.Move
