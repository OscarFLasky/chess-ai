# %%
from fastapi import FastAPI

app = FastAPI(title = "Test  API", version = "0.1.0")

# %%
@app.get("/")
def racine():
    return {"status": "ok"}

# %%
@app.get("/version")
def version():
    return (app.version)
